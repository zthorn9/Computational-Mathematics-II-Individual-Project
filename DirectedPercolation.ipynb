# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import ndimage
import matplotlib.cm as cm
import matplotlib.colors as col

# %%
n = 100
p = 0.72
matrix = np.zeros((n, n))
matrix2 = np.random.rand(n,n)
for i in range(n):
    for j in range(n):
        if matrix2[i,j] < p:
            matrix2[i,j] = 0.66
        else:
            matrix2[i,j] = 0.33
for i in range(n):
    for j in range(n):
        if i%2 == 0:
            if j%2 == 0:
                matrix[i,j] = matrix2[i,j]
        else:
            if j%2 == 1:
                matrix[i,j] = matrix2[i,j]
if matrix[0, int(n/2)] == 0.66:
    matrix[0, int(n/2)] = 1
    for i in range(n-1):
        for j in range(n):
            if 0 < j < n-1:
                if matrix[i,j] == 1:
                    if matrix[i+1, j-1] == 0.66:
                        matrix[i+1, j-1] = 1
                    if matrix[i+1, j+1] == 0.66:
                        matrix[i+1, j+1] = 1
            if j == n-1:
                if matrix[i,j] == 1:
                    if matrix[i+1, j-1] == 0.66:
                        matrix[i+1, j-1] = 1
            if j == 0:
                if matrix[i,j] == 1:
                    if matrix[i+1, j+1] == 0.66:
                        matrix[i+1, j+1] = 1
cmap2 = col.ListedColormap(['#000000', '#52AFE2', '#098663', '#D69605'])
plt.imshow(matrix, cmap = cmap2)
x = 0
for i in range(n):
    if matrix[n-1, i] == 1:
        x = 1
        break
print(x)
# Out:
# 0

# %%
n = 5
p = 0.72
matrix = np.zeros((n, n))
matrix2 = np.random.rand(n,n)
for i in range(n):
    for j in range(n):
        if matrix2[i,j] < p:
            matrix2[i,j] = 0.66
        else:
            matrix2[i,j] = 0.33
for i in range(n):
    for j in range(n):
        if i%2 == 0:
            if j%2 == 0:
                matrix[i,j] = matrix2[i,j]
        else:
            if j%2 == 1:
                matrix[i,j] = matrix2[i,j]
if matrix[0, int(n/2)] == 0.66:
    matrix[0, int(n/2)] = 1
    # for i in range(n-1):
    #     for j in range(n):
    #         if 0 < j < n-1:
    #             if matrix[i,j] == 1:
    #                 if matrix[i+1, j-1] == 0.66:
    #                     matrix[i+1, j-1] = 1
    #                 if matrix[i+1, j+1] == 0.66:
    #                     matrix[i+1, j+1] = 1
    #         if j == n-1:
    #             if matrix[i,j] == 1:
    #                 if matrix[i+1, j-1] == 0.66:
    #                     matrix[i+1, j-1] = 1
    #         if j == 0:
    #             if matrix[i,j] == 1:
    #                 if matrix[i+1, j+1] == 0.66:
    #                     matrix[i+1, j+1] = 1
cmap2 = col.ListedColormap(['#000000', '#52AFE2', '#098663', '#D69605'])
plt.imshow(matrix, cmap = cmap2)
x = 0
for i in range(n):
    if matrix[n-1, i] == 1:
        x = 1
        break
print(x)
# Out:
# 0

# %%
for j in range(n):
    if 0 < j < n-1:
        if matrix[0,j] == 1:
            if matrix[1, j-1] == 0.66:
                matrix[1, j-1] = 1
            if matrix[1, j+1] == 0.66:
                matrix[1, j+1] = 1
    if j == n-1:
        if matrix[0,j] == 1:
            if matrix[1, j-1] == 0.66:
                matrix[1, j-1] = 1
    if j == 0:
        if matrix[0,j] == 1:
            if matrix[1, j+1] == 0.66:
                matrix[1, j+1] = 1

# %%
plt.imshow(matrix, cmap = cmap2)

# %%
for j in range(n):
    if 0 < j < n-1:
        if matrix[1,j] == 1:
            if matrix[2, j-1] == 0.66:
                matrix[2, j-1] = 1
            if matrix[2, j+1] == 0.66:
                matrix[2, j+1] = 1
    if j == n-1:
        if matrix[1,j] == 1:
            if matrix[2, j-1] == 0.66:
                matrix[2, j-1] = 1
    if j == 0:
        if matrix[1,j] == 1:
            if matrix[2, j+1] == 0.66:
                matrix[2, j+1] = 1
plt.imshow(matrix, cmap = cmap2)

# %%
for j in range(n):
    if 0 < j < n-1:
        if matrix[2,j] == 1:
            if matrix[3, j-1] == 0.66:
                matrix[3, j-1] = 1
            if matrix[3, j+1] == 0.66:
                matrix[3, j+1] = 1
    if j == n-1:
        if matrix[2,j] == 1:
            if matrix[3, j-1] == 0.66:
                matrix[3, j-1] = 1
    if j == 0:
        if matrix[2,j] == 1:
            if matrix[3, j+1] == 0.66:
                matrix[3, j+1] = 1
plt.imshow(matrix, cmap = cmap2)

# %%
for j in range(n):
    if 0 < j < n-1:
        if matrix[3,j] == 1:
            if matrix[4, j-1] == 0.66:
                matrix[4, j-1] = 1
            if matrix[4, j+1] == 0.66:
                matrix[4, j+1] = 1
    if j == n-1:
        if matrix[3,j] == 1:
            if matrix[4, j-1] == 0.66:
                matrix[4, j-1] = 1
    if j == 0:
        if matrix[3,j] == 1:
            if matrix[4, j+1] == 0.66:
                matrix[4, j+1] = 1
plt.imshow(matrix, cmap = cmap2)
